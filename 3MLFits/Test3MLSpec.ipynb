# %%
import warnings

warnings.simplefilter("ignore")
import numpy as np
import matplotlib.pyplot as plt
np.seterr(all="ignore")
from threeML import *
from astromodels import *
from astromodels.functions.function import Function1D, FunctionMeta

LMC1halfdeg_pha = "/home/jortecal/GitHub/eRosita/CookBook/srctoolout_000_SourceProducts_00001_1halfdeg_mask30/srctoolout_120_SourceSpec_00001.fits"
LMC1halfdeg_rmf = "/home/jortecal/GitHub/eRosita/CookBook/srctoolout_000_SourceProducts_00001_1halfdeg_mask30/srctoolout_120_RMF_00001.fits"
LMC1halfdeg_arf = "/home/jortecal/GitHub/eRosita/CookBook/srctoolout_000_SourceProducts_00001_1halfdeg_mask30/srctoolout_120_ARF_00001.fits"
# Out:
# 20:58:46 INFO      Starting 3ML!                                                                     ]8;id=5595;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=159177;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#39\39]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=432683;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=71540;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=1152;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=133673;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#41\41]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=263658;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=677863;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#44\44]8;;\
# 20:58:46 WARNING   ROOT minimizer not available                                                ]8;id=749099;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=29171;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=198462;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=778927;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=760901;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=945926;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
#          WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=960417;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=660080;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=78745;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=598034;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=229506;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=54489;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   No fermitools installed                                              ]8;id=786903;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=553540;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=933896;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=570580;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=697159;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=298056;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=8127;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=840322;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %%
spectral_model1 =  TbAbs() * (APEC() + Powerlaw()) + APEC() 

###############################################################################################################################
# Inclusion of the particle background model FWC for TM1
########################################################################################################################################
import re

file_path = "/home/jortecal/Downloads/TM1_FWC_v1.0.dat"

with open(file_path, "r") as f:
    lines = f.readlines()

# Extract the model definition (first line)

# Extract parameter values from the remaining lines
parameters = []
for line in lines[1:]:
    if line.strip():  # Skip empty lines
        parameters.append([float(x) for x in re.split(r"\s+", line.strip())])


# Define the components of the model
constant = Constant()
gaussians = [Gaussian() for _ in range(14)]  # 14 Gaussian components
powerlaw1 = Powerlaw()
powerlaw2 = Powerlaw()

# Define the expfac component
class ExpFac(Function1D, metaclass=FunctionMeta):
    r"""
    description :
        Exponential modification of a spectrum.

        M(E) = 1 + A * exp(-f * E) for E > E_c
               1                   for E <= E_c

    parameters :
        A :
            desc : Amplitude of the exponential modification
            initial value : 1.0
            min : -100.0
            max : 100.0
            delta : 0.1
        f :
            desc : Exponential factor
            initial value : 1.0
            min : -100.0
            max : 100.0
            delta : 0.1
        E_c :
            desc : Start energy of the modification
            initial value : 1.0
            min : -100.0
            max : 100.0
            delta : 0.1
    """

    def _set_units(self, x_unit, y_unit):
        self.A.unit = y_unit
        self.f.unit = 1 / x_unit
        self.E_c.unit = x_unit

    def evaluate(self, x, A, f, E_c):
        return 1 + A * np.exp(-f * x) * (x > E_c)

# Define the bkn2pow component
class Bkn2Pow(Function1D, metaclass=FunctionMeta):
    r"""
    description :
        A three-segment broken power law.

        A(E) = K * E^(-Gamma_1) for E <= E_break1
               K * E_break1^(Gamma_2 - Gamma_1) * E^(-Gamma_2) for E_break1 < E <= E_break2
               K * E_break1^(Gamma_2 - Gamma_1) * E_break2^(Gamma_3 - Gamma_2) * E^(-Gamma_3) for E > E_break2

    parameters :
        K :
            desc : Normalization at 1 keV
            initial value : 1.0
            min : 1e-10
            max : 1e10
            delta : 0.1
        Gamma1 :
            desc : Photon index for E <= E_break1
            initial value : -1.5
            min : -10.0
            max : 10.0
            delta : 0.1
        E_break1 :
            desc : First break energy in keV
            initial value : 10.0
            min : 1e-20
            max : 1e3
            delta : 1.0
        Gamma2 :
            desc : Photon index for E_break1 < E <= E_break2
            initial value : -2.0
            min : -10.0
            max : 10.0
            delta : 0.1
        E_break2 :
            desc : Second break energy in keV
            initial value : 100.0
            min : 1e-20
            max : 1e4
            delta : 1.0
        Gamma3 :
            desc : Photon index for E > E_break2
            initial value : -2.5
            min : -10.0
            max : 10.0
            delta : 0.1
    """

    def _set_units(self, x_unit, y_unit):
        self.K.unit = y_unit
        self.Gamma1.unit = u.dimensionless_unscaled
        self.E_break1.unit = x_unit
        self.Gamma2.unit = u.dimensionless_unscaled
        self.E_break2.unit = x_unit
        self.Gamma3.unit = u.dimensionless_unscaled

    def evaluate(self, x, K, Gamma1, E_break1, Gamma2, E_break2, Gamma3):
        # Define the three segments of the broken power law
        segment1 = K * x**(-Gamma1) * (x <= E_break1)
        segment2 = (
            K
            * E_break1 ** (Gamma2 - Gamma1)
            * x**(-Gamma2)
            * (x > E_break1)
            * (x <= E_break2)
        )
        segment3 = (
            K
            * E_break1 ** (Gamma2 - Gamma1)
            * E_break2 ** (Gamma3 - Gamma2)
            * x**(-Gamma3)
            * (x > E_break2)
        )
        return segment1 + segment2 + segment3

# Instantiate the expfac component
expfac = ExpFac()

# Instantiate the bkn2pow component
bkn2pow = Bkn2Pow()

# Combine the components into a single model
spectral_model_Particle_Background = 
    constant
    * (
        gaussians[0]
        + gaussians[1]
        + gaussians[2]
        + gaussians[3]
        + gaussians[4]
        + gaussians[5]
        + gaussians[6]
        + gaussians[7]
        + gaussians[8]
        + gaussians[9]
        + gaussians[10]
        + gaussians[11]
        + gaussians[12]
        + gaussians[13]
    
    + expfac * (bkn2pow + powerlaw1 + powerlaw2)
)

combined_model =  spectral_model_Particle_Background + spectral_model1

# Create a point source with the spectral model
ModelPlusParticleBackground = PointSource("source", 0, 0, spectral_shape=combined_model)

# Create the final model
model_combined = Model(ModelPlusParticleBackground)

# Display the model
model_combined.display(complete=True)
# Out:
# Model summary:
# ==============
#
#                   N
# Point sources     1
# Extended sources  0
# Particle sources  0
#
# Free parameters (63):
# --------------------
#
#                                         value min_value max_value  \
# source.spectrum.main.composite.k_1        0.0      None      None
# source.spectrum.main.composite.F_2        1.0      None      None
# source.spectrum.main.composite.mu_2       0.0      None      None
# source.spectrum.main.composite.sigma_2    1.0       0.0      None
# source.spectrum.main.composite.F_3        1.0      None      None
# ...                                       ...       ...       ...
# source.spectrum.main.composite.kT_21      1.0      0.08      64.0
# source.spectrum.main.composite.K_22       1.0       0.0    1000.0
# source.spectrum.main.composite.index_22 -2.01     -10.0      10.0
# source.spectrum.main.composite.K_23       1.0       0.0    1000.0
# source.spectrum.main.composite.kT_23      1.0      0.08      64.0
#
#                                                    unit
# source.spectrum.main.composite.k_1       keV-1 s-1 cm-2
# source.spectrum.main.composite.F_2             s-1 cm-2
# source.spectrum.main.composite.mu_2                 keV
# source.spectrum.main.composite.sigma_2              keV
# source.spectrum.main.composite.F_3             s-1 cm-2
# ...                                                 ...
# source.spectrum.main.composite.kT_21                keV
# source.spectrum.main.composite.K_22      keV-1 s-1 cm-2
# source.spectrum.main.composite.index_22
# source.spectrum.main.composite.K_23      keV-1 s-1 cm-2
# source.spectrum.main.composite.kT_23                keV
#
# [63 rows x 4 columns]
#
# Fixed parameters (10):
# ---------------------
#
#                                         value min_value max_value unit
# source.position.ra                        0.0       0.0     360.0  deg
# source.position.dec                       0.0     -90.0      90.0  deg
# source.spectrum.main.composite.piv_18     1.0      None      None  keV
# source.spectrum.main.composite.piv_19     1.0      None      None  keV
# source...redshift_20                      0.0       0.0      15.0
# source.spectrum.main.composite.abund_21   1.0       0.0       5.0
# source...redshift_21                      0.0       0.0      10.0
# source.spectrum.main.composite.piv_22     1.0      None      None  keV
# source.spectrum.main.composite.abund_23   1.0       0.0       5.0
# source...redshift_23                      0.0       0.0      10.0
#
# Properties (3):
# --------------------
#
#                             value  \
# source...abundance_table_20  WILM
# source...abundance_table_21  AG89
# source...abundance_table_23  AG89
#
#                                                               allowed values
# source...abundance_table_20                               [WILM, AG89, ASPL]
# source...abundance_table_21  [Allen, AG89, GA88, Feldman, GA10, Lodd09, AE8]
# source...abundance_table_23  [Allen, AG89, GA88, Feldman, GA10, Lodd09, AE8]
#
# Linked parameters (0):
# ----------------------
#
# (none)
#
# Independent variables:
# ----------------------
#
# (none)
#
# Linked functions (0):
# ----------------------
#
# (none)

# %%
# Assign parameter values from the file

# Assign parameters to the constant component
model_combined.source.spectrum.main.composite.k_1.value = parameters[0][0]  # value of the constant factor
model_combined.source.spectrum.main.composite.k_1.delta = parameters[0][1]  # fit delta
model_combined.source.spectrum.main.composite.k_1.bounds = (parameters[0][2], parameters[0][5])  # min and max
model_combined.source.spectrum.main.composite.k_1.free = False  # fixed parameter
# Assign parameters to the Gaussian components
for i in range(14):  # 14 Gaussian components
    model_combined.source.spectrum.main.composite[f"mu_{i+2}"].value = parameters[1 + i * 3][0]  # mu_i
    model_combined.source.spectrum.main.composite[f"mu_{i+2}"].bounds = (parameters[1 + i * 3][2], parameters[1 + i * 3][5])

    model_combined.source.spectrum.main.composite[f"sigma_{i+2}"].bounds = (parameters[2 + i * 3][2], parameters[2 + i * 3][5])
    model_combined.source.spectrum.main.composite[f"sigma_{i+2}"].value = parameters[2 + i * 3][0]  # sigma_i
    model_combined.source.spectrum.main.composite[f"sigma_{i+2}"].free = False  # fixed parameter

    model_combined.source.spectrum.main.composite[f"F_{i+2}"].value = parameters[3 + i * 3][0]  # F_i
    model_combined.source.spectrum.main.composite[f"F_{i+2}"].bounds = (parameters[3 + i * 3][2], parameters[3 + i * 3][5])

# Assign parameters to the expfac component
model_combined.source.spectrum.main.composite.A_16.value = parameters[-13][0]  # A_16
model_combined.source.spectrum.main.composite.A_16.bounds = (parameters[-13][2], parameters[-13][5])

model_combined.source.spectrum.main.composite.f_16.value = parameters[-12][0]  # f_16
model_combined.source.spectrum.main.composite.f_16.bounds = (parameters[-12][2], parameters[-12][5])

model_combined.source.spectrum.main.composite.E_c_16.value = parameters[-11][0]  # E_c_16
model_combined.source.spectrum.main.composite.E_c_16.bounds = (parameters[-11][2], parameters[-11][5])

# Assign parameters to the broken power law (bkn2pow)

model_combined.source.spectrum.main.composite.Gamma1_17.value = parameters[-10][0] # Gamma1_17
model_combined.source.spectrum.main.composite.Gamma1_17.bounds = (parameters[-10][2], parameters[-10][5])


model_combined.source.spectrum.main.composite.E_break1_17.value = parameters[-9][0] # E_break1_17
model_combined.source.spectrum.main.composite.E_break1_17.bounds = (parameters[-9][2], parameters[-9][5])


model_combined.source.spectrum.main.composite.Gamma2_17.value = parameters[-8][0] # Gamma2_17
model_combined.source.spectrum.main.composite.Gamma2_17.bounds = (parameters[-8][2], parameters[-8][5])


model_combined.source.spectrum.main.composite.E_break2_17.value = parameters[-7][0] # E_break2_17
model_combined.source.spectrum.main.composite.E_break2_17.bounds = (parameters[-7][2], parameters[-7][5])


model_combined.source.spectrum.main.composite.Gamma3_17.value = parameters[-6][0] # Gamma3_17
model_combined.source.spectrum.main.composite.Gamma3_17.bounds = (parameters[-6][2], parameters[-6][5])


model_combined.source.spectrum.main.composite.K_17.bounds = (parameters[-5][2], parameters[-5][5])
model_combined.source.spectrum.main.composite.K_17.value = parameters[-5][0]  # K_17

# Assign parameters to the first power law (powerlaw1)
model_combined.source.spectrum.main.composite.index_18.bounds = (parameters[-4][2], parameters[-4][5])
model_combined.source.spectrum.main.composite.index_18.value = parameters[-4][0]  # index_18

model_combined.source.spectrum.main.composite.K_18.bounds = (1e-20, parameters[-3][5])
model_combined.source.spectrum.main.composite.K_18.value = parameters[-3][0]  # K_18

# Assign parameters to the second power law (powerlaw2)
model_combined.source.spectrum.main.composite.index_19.bounds = (parameters[-2][2], parameters[-2][5])
model_combined.source.spectrum.main.composite.index_19.value = parameters[-2][0]  # index_19

model_combined.source.spectrum.main.composite.K_19.bounds = (1e-20, parameters[-1][5])
model_combined.source.spectrum.main.composite.K_19.value = 1e-20  # K_19

###################################################################################################################################################
###################################################################################################################################################
# We set the parameters of the APEC model and the Powerlaw ****Check with Marco's*** 

model_combined.source.spectrum.main.composite.NH_20 = 4.5e-2
model_combined.source.spectrum.main.composite.NH_20.free = True

# model.APEC.spectrum.main.composite.NH_1 = 4.5e-2 

model_combined.source.spectrum.main.composite.index_22.value = 1.46
model_combined.source.spectrum.main.composite.index_22.free = True



model_combined.source.spectrum.main.composite.kT_21.value = 0.2
model_combined.source.spectrum.main.composite.kT_21.free = True
model_combined.source.spectrum.main.composite.abund_21.value = 1.
model_combined.source.spectrum.main.composite.abund_21.free = False



model_combined.source.spectrum.main.composite.kT_23.value = 0.1
model_combined.source.spectrum.main.composite.kT_23.free = True
model_combined.source.spectrum.main.composite.abund_23.value = 1.
model_combined.source.spectrum.main.composite.abund_23.free = False

###################################################################################################################################################
###################################################################################################################################################

model_combined.display(complete=True)
# Out:
# 21:01:56 WARNING   We have set the min_value of source.spectrum.main.composite.K_18 to 1e-99       ]8;id=120762;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=689561;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/parameter.py#704\704]8;;\
#                   because there was a postive transform
#          WARNING   We have set the min_value of source.spectrum.main.composite.K_19 to 1e-99       ]8;id=947836;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=536180;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/parameter.py#704\704]8;;\
#                   because there was a postive transform
# Model summary:
# ==============
#
#                   N
# Point sources     1
# Extended sources  0
# Particle sources  0
#
# Free parameters (48):
# --------------------
#
#                                              value min_value  \
# source.spectrum.main.composite.F_2        0.001795       0.0
# source.spectrum.main.composite.mu_2        9.57069      9.45
# source.spectrum.main.composite.F_3             0.0       0.0
# source.spectrum.main.composite.mu_3        9.10159       8.8
# source.spectrum.main.composite.F_4         0.00097       0.0
# source.spectrum.main.composite.mu_4        8.19841      8.15
# source.spectrum.main.composite.F_5        0.006867       0.0
# source.spectrum.main.composite.mu_5        8.59208      7.45
# source.spectrum.main.composite.F_6        0.002601       0.0
# source.spectrum.main.composite.mu_6        8.03566       7.8
# source.spectrum.main.composite.F_7         0.00374       0.0
# source.spectrum.main.composite.mu_7        7.44653       7.2
# source.spectrum.main.composite.F_8        0.002479       0.0
# source.spectrum.main.composite.mu_8        7.02454       6.9
# source.spectrum.main.composite.F_9        0.001842       0.0
# source.spectrum.main.composite.mu_9        6.89974       6.8
# source.spectrum.main.composite.F_10        0.01418       0.0
# source.spectrum.main.composite.mu_10       6.38301       6.2
# source.spectrum.main.composite.F_11       0.002771       0.0
# source.spectrum.main.composite.mu_11       5.87841       5.7
# source.spectrum.main.composite.F_12       0.001567       0.0
# source.spectrum.main.composite.mu_12       5.38372       5.3
# source.spectrum.main.composite.F_13       0.000282       0.0
# source.spectrum.main.composite.mu_13       4.52006      4.49
# source.spectrum.main.composite.F_14       0.001548       0.0
# source.spectrum.main.composite.mu_14       3.66144       3.6
# source.spectrum.main.composite.F_15       0.011762       0.0
# source.spectrum.main.composite.mu_15       1.47994      1.47
# source.spectrum.main.composite.A_16           -0.0      -2.0
# source.spectrum.main.composite.f_16       -2.07954      -4.0
# source.spectrum.main.composite.E_c_16         0.05       0.0
# source.spectrum.main.composite.K_17       0.228888       0.0
# source.spectrum.main.composite.Gamma1_17  0.060535      -3.0
# source...E_break1_17                       3.62852       0.0
# source.spectrum.main.composite.Gamma2_17  0.142454      -3.0
# source...E_break2_17                       9.13472       0.0
# source.spectrum.main.composite.Gamma3_17   6.54932      -3.0
# source.spectrum.main.composite.K_18       0.016829       0.0
# source.spectrum.main.composite.index_18    2.16585      -3.0
# source.spectrum.main.composite.K_19            0.0       0.0
# source.spectrum.main.composite.index_19        6.0      -3.0
# source.spectrum.main.composite.NH_20         0.045    0.0001
# source.spectrum.main.composite.K_21            1.0       0.0
# source.spectrum.main.composite.kT_21           0.2      0.08
# source.spectrum.main.composite.K_22            1.0       0.0
# source.spectrum.main.composite.index_22       1.46     -10.0
# source.spectrum.main.composite.K_23            1.0       0.0
# source.spectrum.main.composite.kT_23           0.1      0.08
#
#                                                            max_value  \
# source.spectrum.main.composite.F_2        999999999999999983222784.0
# source.spectrum.main.composite.mu_2                              9.8
# source.spectrum.main.composite.F_3        999999999999999983222784.0
# source.spectrum.main.composite.mu_3                             9.15
# source.spectrum.main.composite.F_4        999999999999999983222784.0
# source.spectrum.main.composite.mu_4                             8.35
# source.spectrum.main.composite.F_5        999999999999999983222784.0
# source.spectrum.main.composite.mu_5                             8.75
# source.spectrum.main.composite.F_6        999999999999999983222784.0
# source.spectrum.main.composite.mu_6                             8.15
# source.spectrum.main.composite.F_7        999999999999999983222784.0
# source.spectrum.main.composite.mu_7                              7.6
# source.spectrum.main.composite.F_8        999999999999999983222784.0
# source.spectrum.main.composite.mu_8                              7.2
# source.spectrum.main.composite.F_9        999999999999999983222784.0
# source.spectrum.main.composite.mu_9                              7.1
# source.spectrum.main.composite.F_10       999999999999999983222784.0
# source.spectrum.main.composite.mu_10                             6.6
# source.spectrum.main.composite.F_11       999999999999999983222784.0
# source.spectrum.main.composite.mu_11                             6.0
# source.spectrum.main.composite.F_12       999999999999999983222784.0
# source.spectrum.main.composite.mu_12                             5.6
# source.spectrum.main.composite.F_13       999999999999999983222784.0
# source.spectrum.main.composite.mu_13                            4.53
# source.spectrum.main.composite.F_14       999999999999999983222784.0
# source.spectrum.main.composite.mu_14                             3.8
# source.spectrum.main.composite.F_15       999999999999999983222784.0
# source.spectrum.main.composite.mu_15                             1.5
# source.spectrum.main.composite.A_16                              2.0
# source.spectrum.main.composite.f_16                              4.0
# source.spectrum.main.composite.E_c_16                      1000000.0
# source.spectrum.main.composite.K_17       999999999999999983222784.0
# source.spectrum.main.composite.Gamma1_17                        10.0
# source...E_break1_17                                       1000000.0
# source.spectrum.main.composite.Gamma2_17                        10.0
# source...E_break2_17                                       1000000.0
# source.spectrum.main.composite.Gamma3_17                        10.0
# source.spectrum.main.composite.K_18       999999999999999983222784.0
# source.spectrum.main.composite.index_18                         10.0
# source.spectrum.main.composite.K_19       999999999999999983222784.0
# source.spectrum.main.composite.index_19                         10.0
# source.spectrum.main.composite.NH_20                         10000.0
# source.spectrum.main.composite.K_21                           1000.0
# source.spectrum.main.composite.kT_21                            64.0
# source.spectrum.main.composite.K_22                           1000.0
# source.spectrum.main.composite.index_22                         10.0
# source.spectrum.main.composite.K_23                           1000.0
# source.spectrum.main.composite.kT_23                            64.0
#
#                                                     unit
# source.spectrum.main.composite.F_2              s-1 cm-2
# source.spectrum.main.composite.mu_2                  keV
# source.spectrum.main.composite.F_3              s-1 cm-2
# source.spectrum.main.composite.mu_3                  keV
# source.spectrum.main.composite.F_4              s-1 cm-2
# source.spectrum.main.composite.mu_4                  keV
# source.spectrum.main.composite.F_5              s-1 cm-2
# source.spectrum.main.composite.mu_5                  keV
# source.spectrum.main.composite.F_6              s-1 cm-2
# source.spectrum.main.composite.mu_6                  keV
# source.spectrum.main.composite.F_7              s-1 cm-2
# source.spectrum.main.composite.mu_7                  keV
# source.spectrum.main.composite.F_8              s-1 cm-2
# source.spectrum.main.composite.mu_8                  keV
# source.spectrum.main.composite.F_9              s-1 cm-2
# source.spectrum.main.composite.mu_9                  keV
# source.spectrum.main.composite.F_10             s-1 cm-2
# source.spectrum.main.composite.mu_10                 keV
# source.spectrum.main.composite.F_11             s-1 cm-2
# source.spectrum.main.composite.mu_11                 keV
# source.spectrum.main.composite.F_12             s-1 cm-2
# source.spectrum.main.composite.mu_12                 keV
# source.spectrum.main.composite.F_13             s-1 cm-2
# source.spectrum.main.composite.mu_13                 keV
# source.spectrum.main.composite.F_14             s-1 cm-2
# source.spectrum.main.composite.mu_14                 keV
# source.spectrum.main.composite.F_15             s-1 cm-2
# source.spectrum.main.composite.mu_15                 keV
# source.spectrum.main.composite.A_16       keV-1 s-1 cm-2
# source.spectrum.main.composite.f_16                keV-1
# source.spectrum.main.composite.E_c_16                keV
# source.spectrum.main.composite.K_17       keV-1 s-1 cm-2
# source.spectrum.main.composite.Gamma1_17
# source...E_break1_17                                 keV
# source.spectrum.main.composite.Gamma2_17
# source...E_break2_17                                 keV
# source.spectrum.main.composite.Gamma3_17
# source.spectrum.main.composite.K_18       keV-1 s-1 cm-2
# source.spectrum.main.composite.index_18
# source.spectrum.main.composite.K_19       keV-1 s-1 cm-2
# source.spectrum.main.composite.index_19
# source.spectrum.main.composite.NH_20                cm-2
# source.spectrum.main.composite.K_21       keV-1 s-1 cm-2
# source.spectrum.main.composite.kT_21                 keV
# source.spectrum.main.composite.K_22       keV-1 s-1 cm-2
# source.spectrum.main.composite.index_22
# source.spectrum.main.composite.K_23       keV-1 s-1 cm-2
# source.spectrum.main.composite.kT_23                 keV
#
# Fixed parameters (25):
# ---------------------
#
#                                           value min_value max_value  \
# source.position.ra                          0.0       0.0     360.0
# source.position.dec                         0.0     -90.0      90.0
# source.spectrum.main.composite.k_1          1.0       0.0      10.0
# source.spectrum.main.composite.sigma_2   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_3   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_4   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_5   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_6   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_7   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_8   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_9   0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_10  0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_11  0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_12  0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_13  0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_14  0.0001       0.0      20.0
# source.spectrum.main.composite.sigma_15  0.0001       0.0      20.0
# source.spectrum.main.composite.piv_18       1.0      None      None
# source.spectrum.main.composite.piv_19       1.0      None      None
# source...redshift_20                        0.0       0.0      15.0
# source.spectrum.main.composite.abund_21     1.0       0.0       5.0
# source...redshift_21                        0.0       0.0      10.0
# source.spectrum.main.composite.piv_22       1.0      None      None
# source.spectrum.main.composite.abund_23     1.0       0.0       5.0
# source...redshift_23                        0.0       0.0      10.0
#
#                                                    unit
# source.position.ra                                  deg
# source.position.dec                                 deg
# source.spectrum.main.composite.k_1       keV-1 s-1 cm-2
# source.spectrum.main.composite.sigma_2              keV
# source.spectrum.main.composite.sigma_3              keV
# source.spectrum.main.composite.sigma_4              keV
# source.spectrum.main.composite.sigma_5              keV
# source.spectrum.main.composite.sigma_6              keV
# source.spectrum.main.composite.sigma_7              keV
# source.spectrum.main.composite.sigma_8              keV
# source.spectrum.main.composite.sigma_9              keV
# source.spectrum.main.composite.sigma_10             keV
# source.spectrum.main.composite.sigma_11             keV
# source.spectrum.main.composite.sigma_12             keV
# source.spectrum.main.composite.sigma_13             keV
# source.spectrum.main.composite.sigma_14             keV
# source.spectrum.main.composite.sigma_15             keV
# source.spectrum.main.composite.piv_18               keV
# source.spectrum.main.composite.piv_19               keV
# source...redshift_20
# source.spectrum.main.composite.abund_21
# source...redshift_21
# source.spectrum.main.composite.piv_22               keV
# source.spectrum.main.composite.abund_23
# source...redshift_23
#
# Properties (3):
# --------------------
#
#                             value  \
# source...abundance_table_20  WILM
# source...abundance_table_21  AG89
# source...abundance_table_23  AG89
#
#                                                               allowed values
# source...abundance_table_20                               [WILM, AG89, ASPL]
# source...abundance_table_21  [Allen, AG89, GA88, Feldman, GA10, Lodd09, AE8]
# source...abundance_table_23  [Allen, AG89, GA88, Feldman, GA10, Lodd09, AE8]
#
# Linked parameters (0):
# ----------------------
#
# (none)
#
# Independent variables:
# ----------------------
#
# (none)
#
# Linked functions (0):
# ----------------------
#
# (none)

# %%
ogip = OGIPLike("ogip", observation=LMC1halfdeg_pha, response=LMC1halfdeg_rmf,  arf_file=LMC1halfdeg_arf)

ogip.set_active_measurements("0.3-9.5")


#***********************************************************************************************************************




jl = JointLikelihood(model_combined,DataList(ogip))

result = jl.fit()


fig = display_spectrum_model_counts(jl,data_color='blue',model_color='red')

fig.set_size_inches(13,10)

ax = fig.get_axes()[0]

ax.set_xlim(left=0.2,right=11)
ax.set_xlabel('Energy [keV]',fontsize=28)
ax.set_ylabel('Rate [counts s$^{-1}$ keV$^{-1}$]',fontsize=28)
ax.set_xscale('log')
ax.set_yscale('log')
# Out:
# 21:37:36 WARNING   Could not find QUALITY in columns or header of PHA file. This is not a valid ]8;id=376361;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/spectrum/pha_spectrum.py\pha_spectrum.py]8;;\:]8;id=377275;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/spectrum/pha_spectrum.py#219\219]8;;\
#                   OGIP file. Assuming QUALITY =0 (good)
#          WARNING   Found TSTOP and TELAPSE. This file is invalid. Using TSTOP.                  ]8;id=703909;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/spectrum/pha_spectrum.py\pha_spectrum.py]8;;\:]8;id=494242;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/spectrum/pha_spectrum.py#274\274]8;;\
#          INFO      Auto-probed noise models:                                                    ]8;id=239599;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=305885;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py#490\490]8;;\
#          INFO      - observation: poisson                                                       ]8;id=513296;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=811306;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py#491\491]8;;\
#          INFO      - background: None                                                           ]8;id=495431;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=208507;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py#492\492]8;;\
#          INFO      Range 0.3-9.5 translates to channels 38-895                                 ]8;id=350755;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=288913;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py#1247\1247]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=912352;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=869804;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1046\1046]8;;\
# 21:38:26 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=869231;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=162095;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02454000e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38301000e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=384120;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=262904;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02454000e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38301000e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:38:40 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=892491;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=824891;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38301000e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:38:56 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=781165;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=975715;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=665749;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=347485;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:39:01 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=84229;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=207765;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=689062;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=843990;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -1.52940262e-08 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=135072;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=49488;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -9.23698610e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:39:02 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=229180;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=16794;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -2.70673978e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=502956;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=168842;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -2.85816578e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:39:03 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=527329;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=372968;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.00959178e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 5.47232686e+19             ]8;id=906969;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=794745;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 2.96418540e+19             ]8;id=999073;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=877756;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=575618;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=291546;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57160579e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=424930;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=666434;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57143916e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=890802;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=574495;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57153080e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=978620;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=276604;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57151414e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=654316;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=565904;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  6.16777447e+22  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:39:04 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=327538;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=668209;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  6.07413673e+22  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=794148;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=986020;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.14402233e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=795708;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=616703;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.02816402e+00
#                     9.53674013e+17  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=134697;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=52129;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     6.16777447e+22  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=205639;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=153069;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     6.07413673e+22  8.19841000e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=477859;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=576992;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.24579545e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
#          WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=160111;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=287778;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.16365558e+00  9.53674013e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# 21:39:05 WARNING   These parameters returned a logLike = Nan: [ 9.53674013e+17             ]8;id=972417;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=375785;file:///home/jortecal/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py#1006\1006]8;;\
#                   9.57152247e+00  9.53674013e+17  9.10159000e+00
#                     9.53674013e+17  8.19841000e+00  9.60263209e+17  8.59241151e+00
#                     9.53674013e+17  8.03566000e+00  9.53674013e+17  7.44653000e+00
#                     9.53674013e+17  7.02085275e+00  9.53674013e+17  6.89974000e+00
#                     9.53674013e+17  6.38273184e+00  9.53674013e+17  5.87841000e+00
#                     9.53674013e+17  5.38372000e+00  9.53674013e+17  4.52006000e+00
#                     9.53674013e+17  3.66144000e+00  9.53674013e+17  1.47994000e+00
#                    -3.17994603e-09 -2.07954000e+00  5.00000000e-02  9.53674013e+17
#                     6.05347000e-02  3.62852000e+00  1.42454000e-01  9.13472000e+00
#                     6.54932000e+00 -1.77394943e+00  2.16585000e+00 -1.99999580e+01
#                     6.00000000e+00 -1.34678749e+00  2.70616862e-16  2.00000000e-01
#                     2.70616862e-16  1.46000000e+00  2.70616862e-16  1.00000000e-01]
# ...
#     628 # Gather the best fit values from the minimizer and the covariance matrix (if provided)
#     630 try:
# --> 632     internal_best_fit_values, function_minimum = self._minimize()
#     634 except FitFailed:
#     636     raise
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/minimizer/minuit_minimizer.py:193, in MinuitMinimizer._minimize(self)
#     190 # Try a maximum of 10 times and break as soon as the fit is ok
#     192 self.minuit.reset()
# --> 193 self._last_migrad_results = self.minuit.migrad()
#     195 for i in range(9):
#     197     if self.minuit.valid:
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/iminuit/minuit.py:789, in Minuit.migrad(self, ncall, iterate, use_simplex)
#     787 t = mutil._Timer(self._fmin)
#     788 with t:
# --> 789     fm = _robust_low_level_fit(
#     790         self._fcn,
#     791         self._last_state,
#     792         replace_none(ncall, 0),
#     793         self._strategy,
#     794         self._tolerance,
#     795         self._precision,
#     796         iterate,
#     797         use_simplex,
#     798     )
#     800 self._last_state = fm.state
#     802 self._fmin = mutil.FMin(
#     803     fm,
#     804     "Migrad",
#    (...)
#     809     t.value,
#     810 )
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/iminuit/minuit.py:2755, in _robust_low_level_fit(fcn, state, ncall, strategy, tolerance, precision, iterate, use_simplex)
#    2753 if precision is not None:
#    2754     simplex.precision = precision
# -> 2755 fm = simplex(ncall, tolerance)
#    2756 # recreate MnMigrad instance to start from updated state
#    2757 migrad = MnMigrad(fcn, fm.state, strategy)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/classicMLE/joint_likelihood.py:980, in JointLikelihood.minus_log_like_profile(self, *trial_values)
#     976 for dataset in list(self._data_list.values()):
#     978     try:
# --> 980         this_log_like = dataset.inner_fit()
#     982     except ModelAssertionViolation:
#     983
#     984         # This is a zone of the parameter space which is not allowed. Return
#     985         # a big number for the likelihood so that the fit engine will avoid it
#     987         log.warning(
#     988             "Fitting engine in forbidden space: %s" % (trial_values,),
#     989         )
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py:1906, in SpectrumLike.inner_fit(self)
#    1904 def inner_fit(self) -> float:
# -> 1906     return self.get_log_like()
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py:1898, in SpectrumLike.get_log_like(self, precalc_fluxes)
#    1888 def get_log_like(
#    1889     self, precalc_fluxes: Optional[np.ndarray] = None
#    1890 ) -> float:
#    1891     """
#    1892     Calls the likelihood from the pre-setup likelihood evaluator that "knows" of the currently set
#    1893     noise models
#    1894
#    1895     :return:
#    1896     """
# -> 1898     loglike, _ = self._likelihood_evaluator.get_current_value(
#    1899         precalc_fluxes=precalc_fluxes
#    1900     )
#    1901     if self._exclude_from_fit: loglike*=0
#    1902     return loglike
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/spectrum/spectrum_likelihood.py:218, in PoissonObservedNoBackgroundStatistic.get_current_value(self, precalc_fluxes)
#     214 def get_current_value(self, precalc_fluxes: Optional[np.array]=None):
#     215     # In this likelihood the background becomes part of the model, which means that
#     216     # the uncertainty in the background is completely neglected
# --> 218     model_counts = self._spectrum_plugin.get_model(precalc_fluxes=precalc_fluxes)
#     220     background_model_counts = np.zeros_like(model_counts)
#     222     loglike, _ = poisson_log_likelihood_ideal_bkg(
#     223         self._spectrum_plugin.current_observed_counts,
#     224         background_model_counts,
#     225         model_counts,
#     226     )
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py:1995, in SpectrumLike.get_model(self, precalc_fluxes)
#    1987     (model,) = self._rebinner.rebin(
#    1988         self._evaluate_model(precalc_fluxes=precalc_fluxes)
#    1989         * self._observed_spectrum.exposure
#    1990     )
#    1992 else:
#    1994     model = (
# -> 1995         self._evaluate_model(precalc_fluxes=precalc_fluxes)[self._mask]
#    1996         * self._observed_spectrum.exposure
#    1997     )
#    1999 return self._nuisance_parameter.value * model
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/DispersionSpectrumLike.py:142, in DispersionSpectrumLike._evaluate_model(self, precalc_fluxes)
#     134 def _evaluate_model(
#     135     self, precalc_fluxes: Optional[np.array] = None
#     136 ) -> np.ndarray:
#     137     """
#     138     evaluates the full model over all channels
#     139     :return:
#     140     """
# --> 142     return self._response.convolve(precalc_fluxes=precalc_fluxes)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/utils/OGIP/response.py:251, in InstrumentResponse.convolve(self, precalc_fluxes)
#     247 if precalc_fluxes is None:
#     249     try:
# --> 251         fluxes = self._integral_function(
#     252             # self._monte_carlo_energies[:-1], self._monte_carlo_energies[1:]
#     253         )
#     254     except (TypeError):
#     256         fluxes = self._integral_function(
#     257             self._monte_carlo_energies[:-1],
#     258             self._monte_carlo_energies[1:],
#     259         )
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py:2167, in SpectrumLike._get_diff_flux_and_integral.<locals>.integral()
#    2165 def integral():
# -> 2167     diff_fluxes_edges = differential_flux(e_edges)
#    2168     diff_fluxes_mid = differential_flux(e_m)
#    2170     return _simps(
#    2171         ee1, ee2, diff_fluxes_edges, diff_fluxes_mid
#    2172     )
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/threeML/plugins/SpectrumLike.py:2084, in SpectrumLike._get_diff_flux_and_integral.<locals>.differential_flux(energies)
#    2083 def differential_flux(energies):
# -> 2084     fluxes = likelihood_model.get_point_source_fluxes(
#    2085         0, energies, tag=self._tag, stokes=self._stokes
#    2086     )
#    2088     # If we have only one point source, this will never be executed
#    2089     for i in range(1, n_point_sources):
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/model.py:1389, in Model.get_point_source_fluxes(self, id, energies, tag, stokes)
#    1372 def get_point_source_fluxes(
#    1373     self, id: int, energies: np.ndarray, tag=None, stokes=None
#    1374 ) -> np.ndarray:
#    1375     """
#    1376     Get the fluxes from the id-th point source
#    1377
#    (...)
#    1386     :return: fluxes
#    1387     """
# -> 1389     return list(self._point_sources.values())[id](
#    1390         energies, tag=tag, stokes=stokes
#    1391     )
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/sources/point_source.py:203, in PointSource.__call__(self, x, tag, stokes)
#     196         return sum(results)
#     198     else:
#     199
#     200         # Fast version without units, where x is supposed to be in the same units as currently defined in
#     201         # units.get_units()
# --> 203         results = numpy.array([component(x, stokes) for component in list(self.components.values())]
#     204                               )
#     206         return _sum(results)
#     208 else:
#     209
#     210     # Time-varying or energy-varying or whatever-varying
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/spectral_component.py:71, in SpectralComponent.__call__(self, energies, stokes)
#      70 def __call__(self, energies, stokes=None):
# ---> 71     spec = self.shape(energies)
#      72     if stokes == 'Q' or stokes == 'U':
#      73         spec *= self._polarization(energies, stokes)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:2339, in CompositeFunction.__call__(self, x)
#    2337 def __call__(self, x):
# -> 2339     return self.evaluate(self._np_operator, self._f1, self._f2, x)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:1947, in _cf_evaluate_func_func(np_operator, f1, f2, *args)
#    1944 def _cf_evaluate_func_func(np_operator, f1, f2, *args):
#    1945     # Evaluate for when both elements are functions
# -> 1947     return np_operator(f1(*args), f2(*args))
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:2339, in CompositeFunction.__call__(self, x)
#    2337 def __call__(self, x):
# -> 2339     return self.evaluate(self._np_operator, self._f1, self._f2, x)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:1947, in _cf_evaluate_func_func(np_operator, f1, f2, *args)
#    1944 def _cf_evaluate_func_func(np_operator, f1, f2, *args):
#    1945     # Evaluate for when both elements are functions
# -> 1947     return np_operator(f1(*args), f2(*args))
#
#     [... skipping similar frames: CompositeFunction.__call__ at line 2339 (1 times), _cf_evaluate_func_func at line 1947 (1 times)]
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:2339, in CompositeFunction.__call__(self, x)
#    2337 def __call__(self, x):
# -> 2339     return self.evaluate(self._np_operator, self._f1, self._f2, x)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:1947, in _cf_evaluate_func_func(np_operator, f1, f2, *args)
#    1944 def _cf_evaluate_func_func(np_operator, f1, f2, *args):
#    1945     # Evaluate for when both elements are functions
# -> 1947     return np_operator(f1(*args), f2(*args))
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:1453, in Function1D.__call__(self, x)
#    1445 if isinstance(x, np.ndarray):
#    1446
#    1447     # We have an array as input (or a single quantity)
#    1449     if not isinstance(x, u.Quantity):
#    1450
#    1451         # This is a normal array, let's use the fast call (without units)
# -> 1453         return self.fast_call(x)
#    1455     else:
#    1456
#    1457         # This is an array with units or a single quantity, let's use the slow call which preserves units
#    1459         if self.y_unit is None:
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/core/memoization.py:56, in memoize.<locals>.memoizer(instance, x, *args, **kwargs)
#      49 @functools.wraps(method)
#      50 def memoizer(instance, x, *args, **kwargs):
#      52     if not _WITH_MEMOIZATION or isinstance(x, u.Quantity):
#      53
#      54         # Memoization is not active or using units, do not use memoization
# ---> 56         return method(instance, x, *args, **kwargs)
#      58     # Create a tuple because a tuple is hashable
#      60     unique_id = tuple(
#      61         float(yy.value) for yy in list(instance.parameters.values())
#      62     ) + (x.size, x.min(), x.max())
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/function.py:1560, in Function1D.fast_call(self, x)
#    1548 @memoize
#    1549 def fast_call(self, x) -> np.ndarray:
#    1550
#    (...)
#    1555
#    1556     # values = list(map(attrgetter("value"), self._get_children()))
#    1558     values = list(map(attrgetter("value"), self._get_parameters()))
# -> 1560     return self.evaluate(x, *values)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/astromodels/functions/functions_1D/apec.py:149, in APEC.evaluate(self, x, K, kT, abund, redshift)
#     117 sess.set_response(ebounds, raw=True)
#     119 sess.set_abund(
#     120     [
#     121         6,
#    (...)
#     146     abund,
#     147 )
# --> 149 spec = sess.return_spectrum(kT) / binsize / 1e-14
#     151 return K * spec
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/pyatomdb/spectrum.py:2412, in CIESession.return_spectrum(self, te, teunit, nearest, get_nearest_t, log_interp)
#    2410 self.spectra.ebins = self.specbins
#    2411 self.spectra.ebins_checksum=hashlib.md5(self.spectra.ebins).hexdigest()
# -> 2412 s= self.spectra.return_spectrum(te, teunit=teunit, nearest=nearest,\
#    2413                                 elements = el_list, abundance=ab, \
#    2414                                 broaden_object = self.cdf, \
#    2415                                 log_interp=log_interp, dolines=self.dolines,\
#    2416                                 dopseudo=self.dopseudo, docont=self.docont, \
#    2417                                 do_eebrems = self.do_eebrems)
#    2418 ss = self._apply_response(s)
#    2420 return ss
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/pyatomdb/spectrum.py:4133, in _CIESpectrum.return_spectrum(self, Te, teunit, nearest, elements, abundance, log_interp, broaden_object, dolines, docont, dopseudo, do_eebrems)
#    4120   ss = self.spectra[ikT[0]][Z].return_spectrum(self.ebins,\
#    4121                           Tb,\
#    4122                           ebins_checksum = self.ebins_checksum,\
#    (...)
#    4129                           dopseudo=dopseudo) *\
#    4130                           abund
#    4132 else:
# -> 4133   ss1 = self.spectra[ikT[0]][Z].return_spectrum(self.ebins,\
#    4134                           Tb,\
#    4135                           ebins_checksum = self.ebins_checksum,\
#    4136                           thermal_broadening = self.thermal_broadening,\
#    4137                           broaden_limit = epslimit,\
#    4138                           velocity_broadening = self.velocity_broadening,\
#    4139                           broaden_object=broaden_object,\
#    4140                           dolines=dolines,\
#    4141                           docont=docont,\
#    4142                           dopseudo=dopseudo) *\
#    4143                           abund
#    4145   ss2 = self.spectra[ikT[1]][Z].return_spectrum(self.ebins,\
#    4146                           Tb,\
#    4147                           ebins_checksum = self.ebins_checksum,\
#    (...)
#    4154                           dopseudo=dopseudo) *\
#    4155                           abund
#    4157   ss = self._merge_spectra_temperatures(f,ss1,ss2,log_interp)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/pyatomdb/spectrum.py:4857, in _ElementSpectrum.return_spectrum(self, eedges, Te, ebins_checksum, thermal_broadening, broaden_limit, velocity_broadening, teunit, broaden_object, dolines, docont, dopseudo)
#    4854 spec = numpy.zeros(len(eedges)-1)
#    4856 if dolines:
# -> 4857   spec+=self.lines.return_spec(eedges, T, ebins_checksum=ebins_checksum,\
#    4858                               thermal_broadening=thermal_broadening,\
#    4859                               broaden_limit=broaden_limit,\
#    4860                               velocity_broadening=velocity_broadening,\
#    4861                               broaden_object=broaden_object)
#    4862 if dopseudo+docont > 0:
#    4863   spec+=self.continuum.return_spec(eedges, ebins_checksum = ebins_checksum,\
#    4864                                    dopseudo=dopseudo, docont=docont)
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/pyatomdb/spectrum.py:5275, in _LineData.return_spec(self, eedges, T, ebins_checksum, thermal_broadening, velocity_broadening, broaden_limit, broaden_object)
#    5272   pass
#    5274 else:
# -> 5275   spec,z = numpy.histogram(self.lineenergies, \
#    5276                            bins=eedges, \
#    5277                            weights = self.lines['Epsilon'])
#    5278   self.spectrum = spec
#    5279   self.spectrum_calculated = True
#
# File ~/GitHub/eRosita/.venv/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:894, in histogram(a, bins, range, density, weights)
#     892 sa = tmp_a[sorting_index]
#     893 sw = tmp_w[sorting_index]
# --> 894 cw = np.concatenate((zero, sw.cumsum()))
#     895 bin_index = _search_sorted_inclusive(sa, bin_edges)
#     896 cum_n += cw[bin_index]
#
# KeyboardInterrupt:
